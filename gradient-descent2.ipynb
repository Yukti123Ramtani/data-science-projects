# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import math
import matplotlib.pyplot as plt

# %%
def gradient_descent(x,y):
    m_curr=b_curr=0
    iterations=10
    learningrate=.001
    
    n=len(x)
    for i in range(iterations):
        y_predicted=m_curr*x+b_curr
        cost=(1/n)*sum([val**2 for val in (y-y_predicted)])
        md=-(2/n)*sum(x*(y-y_predicted))
        bd=-(2/n)*sum(y-y_predicted)
        m_curr=m_curr-learningrate*md
        b_curr=b_curr-learningrate*bd
        plt.plot(x,y_predicted,color="green")
        print("m{},b{},cost{},iteration{}".format(m_curr,b_curr,cost,i))

# %%
x=np.array([1,2,3,4,5])
y=np.array([5,7,9,11,13])
gradient_descent(x,y)
# Out:
# m0.062,b0.018000000000000002,cost89.0,iteration0
# m0.122528,b0.035592000000000006,cost84.881304,iteration1
# m0.181618832,b0.052785648000000004,cost80.955185108544,iteration2
# m0.239306503808,b0.069590363712,cost77.21263768455901,iteration3
# m0.29562421854195203,b0.086015343961728,cost73.64507722605434,iteration4
# m0.35060439367025875,b0.10206956796255283,cost70.2443206760065,iteration5
# m0.40427867960173774,b0.11776180246460617,cost67.00256764921804,iteration6
# m0.4566779778357119,b0.13310060678206653,cost63.912382537082294,iteration7
# m0.5078324586826338,b0.14809433770148814,cost60.966677449199324,iteration8
# m0.5577715785654069,b0.16275115427398937,cost58.15869595270883,iteration9

# %%
df=pd.read_csv("/kaggle/input/test-scores-csv/test_scores.csv")
r=LinearRegression()
r.fit(df[["math"]],df.cs)
# Out:
# LinearRegression()

# %%
r.coef_
# Out:
# array([1.01773624])

# %%
r.intercept_
# Out:
# np.float64(1.9152193111569034)

# %%
def gradient_descent(x,y):
    m_curr=b_curr=0
    iterations=10000
    n=len(x)
    learning_rate=.01
    cost_previous=0
    for i in range(iterations):
        y_predicted=m_curr*x+b_curr
        cost=(1/n)*sum([val**2 for val in (y-y_predicted)])
        md=(-2/n)*sum(x*(y-y_predicted))
        bd=(-2/n)*sum(y-y_predicted)
        if math.isclose(cost,cost_previous,rel_tol=1e-20):
            break
        cost_previous=cost
        print("m{},b{},cost{},iteration{}".format(m_curr,b_curr,cost,i))
    return m_curr,b_curr

# %%
x=np.array(df.math)
y=np.array(df.cs)
m,b=gradient_descent(x,y)
print("using gradient descent function coef{},intercept{}".format(x,y))
print("using sklearn: coef{},intercept{}".format(r.coef_,r.intercept_))
# Out:
# m0,b0,cost5199.1,iteration0
# using gradient descent function coef[92 56 88 70 80 49 65 35 66 67],intercept[98 68 81 80 83 52 66 30 68 73]
# using sklearn: coef[1.01773624],intercept1.9152193111569034
